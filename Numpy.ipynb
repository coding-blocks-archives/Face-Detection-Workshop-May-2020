# %%
! pip install numpy
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import numpy as np

# %%
a = np.array([24,7,9,10])

# %%
a
# Out:
# array([24,  7,  9, 10])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (4,)

# %%
a2 = np.array([[3,5,8], 
               [4,2,1]])

# %%
a2
# Out:
# array([[3, 5, 8],
#        [4, 2, 1]])

# %%
a2.shape
# Out:
# (2, 3)

# %%
a3 = np.array([[[3,4], [1,5], [90, 87]]])

# %%
a3
# Out:
# array([[[ 3,  4],
#         [ 1,  5],
#         [90, 87]]])

# %%
a3.shape
# Out:
# (1, 3, 2)

# %%
a3.ndim
# Out:
# 3

# %%
a2.ndim
# Out:
# 2

# %%
rand_mat = np.random.randint(low = 1, high = 100, size=(5,5))

# %%
rand_mat
# Out:
# array([[26, 44, 20, 64,  8],
#        [23, 38, 26, 51, 54],
#        [79, 18, 99, 68, 72],
#        [36, 13, 49, 66, 16],
#        [50, 12, 53, 19, 56]])

# %%
rand_mat[0,0]
# Out:
# 26

# %%
rand_mat[-1 , -1 ]
# Out:
# 56

# %%
# array slicing
# arr[ rows , cols ]
rand_mat[  2:5  , 1:4 ]
# Out:
# array([[18, 99, 68],
#        [13, 49, 66],
#        [12, 53, 19]])

# %%
rand_mat[2:4 , :-1]
# Out:
# array([[79, 18, 99, 68],
#        [36, 13, 49, 66]])

# %%
np.abs(-5)
# Out:
# 5

# %%
np.sin(0)
# Out:
# 0.0

# %% [markdown]
# ## Matplotlib

# %%
# ! pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread("./meowth.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (250, 250, 3)

# %%
plt.imshow(img)

# %%
meowth_face = img[ 120:180  ,   70:170  , : ]

# %%
plt.imshow(meowth_face)
