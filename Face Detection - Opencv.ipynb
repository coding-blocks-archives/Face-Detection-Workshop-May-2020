# %%
# ! pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = plt.imread("group-photo1.png")

# %%
img.shape
# Out:
# (385, 600, 3)

# %%
plt.imshow(img)

# %%
detector = cv2.CascadeClassifier("haarcascade_frontalface_alt (1).xml")

# %%
faces = detector.detectMultiScale(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-83d29b2ef7f2> in <module>
# ----> 1 faces = detector.detectMultiScale(img)
#
# error: OpenCV(4.1.1) /Users/travis/build/skvark/opencv-python/opencv/modules/objdetect/src/cascadedetect.cpp:1389: error: (-215:Assertion failed) scaleFactor > 1 && _image.depth() == CV_8U in function 'detectMultiScale'

# %%
faces

# %%
for face in faces:
    x,y, w, h = face
    
    img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,255,255), 3)

# %%
# x,y,w,h = faces[0]

# %%
# modified_img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,255,255), 2)

# %%
# plt.imshow(modified_img)

# %%
plt.imshow(img)
